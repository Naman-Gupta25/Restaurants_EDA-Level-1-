# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.graph_objects as pg

# %%
df=pd.read_csv("Dataset  (1).csv")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
#  Checking for Duplicates Values


df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking For Null Values :


df.isna().sum()


# There are 9 Null Values in Cuisines .
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# # introduction
#
# this dataset contains the data regarding the resturants :
#
#  it has 21 columns .
#
#  it has 9551 Rows .
#
#  it has No Duplicates Values .
#
#  it has 9 null values in Cuisines Column.
#
#  There is some Spelling errors in some rows.
#
#  There is no uniform average price for two , it varies with country.
#
#  there is Uniform Price Range for every different Currencies .
#
#
#
# # Coulumns identification :
#
# ## Categorical :
#     Resturant NAme
#     Country Code
#     City
#     Address
#     Locality
#     Locality Verbose
#     Longitude
#     Latitude
#     Switch With order Menu
#     Rating Color
#     Currency
#     Cuisines
#     Has Table Booking
#     Has Online Delivery
#     Is Delivering Now
#     Price Range
#     Rating text
#
#
#
# ## Numerical :
#     Resturant Id
#     Average Cost for two
#     Aggregate Rating
#     Votes

# %% [markdown]
# # Univariate Analysis

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# # checking inviduals columns :
#
#
# 1. resturant id :
#    it has no null and duplicates values
#
#
# 2.Restaurant Name :
#    it has duplicates names in the same city but with different address
#    it has irregular alphabets ,need to check the spellings
#
# 3.Country Code :
#    it has the data of restaurant in 15 country . country code are irregular/vague Doesn't Coincide with Acual Country Code
#    there are 8652 restaurants data of India , 434 of US ,80 of UK ,60-60-60 of Brazil ,South Africa and UAE respectively   .
#
# 4.City :
#    it has the data 141 cities .
#    it has spelling error in istanbul, braslia , Sauao Paulo
#
# 5.Address:
#    it has different address although it has floor in some address .
#
# 6.Locality :
#    it has nearby famous area but to use it i need to get the famousness of areas separately .
#
# 7. Locality Verbose :
#    it contains the same as locality but it also adds city .
#
# 8.Langitude and Longitude :  USELESS
#    it has different values but it cannot be helpful as this does not relates with restaurant popularity
#
# 9. Cuisuines :
#     isme multiple cuisines h jisko split krke alag alag krna hoga
#     fir isme ye analysis krr skte h ki kitne cuisines se kitna famous hote ya sirf ek me specialist me jada popularity hoti h.
#     it has null 9 values, need to deal with it .
#     null values wale me table booking , online booking , online delivery nhi h , these are typical old cafes
#
# 10.'Average Cost for two' and ''Currency :
#    there is difference in the currency hence it value variates with currency and there cannot be comparison between them
#    to Compare them we need to change them in one uniform value which is Indian Rupees .
#
# 11. Has Table booking , Has online booking, is delivering now  :
#     it simply answers in yes and no .
#     in table booking , there 8393 No's and 1158 Yes'
#     in online booking  there are 7100 No's and 2451 Yes'
#     is delivering now , there are 9517 No's and 34 yes's
#
#
#     now they can be used as ki same cateogory me inse ka effect padta h but there can be no much effect as there are maximum nos
#
#
# 12.'Switch to order menu':    USELESS
#    it is usless column as there is only nos , which doesn't contribute to Analysis
#
# 13. Price range :
#    isme Average Cost for two ke basis pr 4 category banae gyi h
#    the value counts denotes the prefferencve of customers .
#    Now there is no Distinct Average Cost for two Regarding Price range .
#
#
# 14. rating Text and rating color indicates to same range  - ISME EK COLUMN HI USEFUL H WHICH IS RATING TEXT
#    rating color me :
#
#     **There_is_Irregular_Period_of_Distribution**
#
#       dark green for 4.5 to 4.9 --- Excellant
#
#       green for 4.0 to 4.4 --- Very Good
#
#       yellow for 3.5 to 3.9 --- Good
#
#       orange for 2.5 to 3.4 --- Average
#
#       red for 1.8 to 2.4 or maybe for greate than 0 but less than 2.4 --- Poor Rating
#
#       white is for 0 rating only --- Not Rated
#
# 15. Aggregate Rating ko rakhna for group by
#
# 16. Votes - it is helpful in ranking resturants in same category .

# %% [markdown]
# # Feature Enginnering :
#
#
#
# ## tasks:
#     1.Spelling Correction
#
#     2. Fetching COuntry Name from teh Data .
#
#     3. Droping Langitude and Longitude,Locality Verbose, 'Switch to order menu', Currency and Rating Color
#
#     4.All different Cuisines are in a list , need to split it .
#
#     5.Changing the Average Cost in uniform  Currency with one dictionary as there are 12 different currencies .
#
#     6.Dealing with Missing Values .
#
#     7. Add a columns with number of cuisines .

# %% [markdown]
# # Assumption / Findings / Metrices For Analysis
#
#  Extra:
#
#     Restaurant Names Helps us to Find top 10 Resturants with most Franchises/ Chains
#
#     IS Franchise or Individual are more Trusted by Customers (Customer Behavior Toward Franchises.)
#
#     In Cities , like Delhi Restaurants are concentrated towards few localities, we can analyse on the basis of same locality and find patterns  on the basis of paramets of rating ,votes,cuisines .
#
#     Finding Relevence of Price Range its reliance on different parameters.
#
#     If restaurants address contains public space like park , mall ,etc. Analyzing  its effects
#
# Country Based
#
#     1. Country and their numbers of restaurants
#
#     2.Top Franchise in that country and on the basis of rating of Franchise
#
#     3. Distibution of Restaurants along different parts of Country.
#
#     4. Cuisines offered in COuntries and its Distribution .
#
#     5. On the basis of Average Cost .
#
#
# On City Basis :
#
#     1.  overall Top Cities
#
#     2. Restaurants in Cities in Respected Countries .
#
#     3. Cuisines available in different City .
#
#     4.  Most Popular Cuisine in Cities .
#
#     5. Varience in Average Cost on the Basis Of City .
#
#     6. Varience on teh basis of Price Range Along Cities .
#
#     7. Top Franchises In Cities ,etc.
#
# On Cuisines Basis :
#
#     1. Famous Cuisines in Different Countries , Cities .
#
#     2. Overll Famous Cuisines.
#
#     3. Explicit Cuisines Popularity .
#
#     4.Top Restaurant on the basis of Different Cuisines on the parameter of Rating and Votes and Locality  .
#
#
# Distribution of Average Cost for two in Price Range on the basis of Countries .

# %%
df['Restaurant ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Restaurant Name'].duplicated().sum()
# Out:
# np.int64(2105)

# %%
df['Country Code'].nunique()
df['Country Code'].value_counts()
# Out:
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
df['Currency'].unique()
df['Currency'].nunique()
df['Currency'].value_counts()
# Out:
# Currency
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Rand(R)                     60
# Emirati Diram(AED)          60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: count, dtype: int64

# %%
df['Price range'].unique()
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
df[(df['Country Code']==1) & (df['Price range']==2)]['Average Cost for two'].value_counts().sort_index()
# Out:
# Average Cost for two
# 250      1
# 300      3
# 350     11
# 400     30
# 450     15
# 500    879
# 550    180
# 600    636
# 650    175
# 700    394
# 720      1
# 750     64
# 800    305
# 850     48
# 900     96
# 950     20
# Name: count, dtype: int64

# %%
df[(df['Country Code']==1) & (df['Price range']==2)]
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 635         3400019                 Dasaprakash Restaurant             1
# 641         3400105                              Pizza Hut             1
# ...             ...                                    ...           ...
# 9269       18285610                            Six Degrees             1
# 9270        2800128             Sea Inn - Raju Gaari Dhaba             1
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
#
#        City                                            Address     Locality  \
# ...

# %%
new_df= pd.read_csv("Dataset  (1).csv")
new_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
new_df['Cuisines']=new_df['Cuisines'].str.split(',')
new_df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
new_df=new_df.explode('Cuisines')
new_df['Cuisines']= new_df['Cuisines'].str.strip()
new_df['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian      3960
# Chinese           2735
# Fast Food         1986
# Mughlai            995
# Italian            764
#                   ...
# Cuisine Varies       1
# Fish and Chips       1
# Durban               1
# D�_ner               1
# B�_rek               1
# Name: count, Length: 145, dtype: int64

# %% [markdown]
# # Dealing with Missing Values .
#
# Here , we can't just fill this value , so we will drop it .

# %%
df[df['Cuisines'].isnull()]
df[df['Country Code']==216]
new_df[new_df['Country Code']==216]['Cuisines'].value_counts()
# Out:
# Cuisines
# American          112
# Seafood            59
# Sandwich           49
# Burger             49
# Pizza              49
# Steak              42
# Italian            38
# Breakfast          37
# Mexican            36
# Sushi              34
# BBQ                30
# Japanese           28
# Bar Food           26
# Southern           24
# Asian              23
# Vegetarian         22
# Chinese            22
# Desserts           20
# Thai               19
# Tapas              12
# International      12
# Mediterranean      10
# Cajun               9
# Latin American      8
# Greek               8
# Indian              8
# Hawaiian            8
# Southwestern        7
# Coffee and Tea      7
# Caribbean           7
# European            6
# Spanish             6
# Diner               6
# Fast Food           6
# German              6
# Vietnamese          5
# Ice Cream           3
# Middle Eastern      3
# French              3
# New American        2
# Brazilian           2
# ...

# %%
df=df.dropna()
new_df=new_df.dropna()

# %% [markdown]
# # Visualization:

# %% [markdown]
# # Countries and Number of Restaurant

# %%
f=sns.countplot(data=df,x='Country Code')
f.set_xticklabels(['India','Australia','Brazil','Canada','Indonesia','New Zealand','Philippines','Qatar','Singapore','South Africa','Sri Lanka','Turkey','UAE','UK','USA'],rotation=90)
f.bar_label(f.containers[0],)
plt.show()
# Out:
# C:\Users\naman\AppData\Local\Temp\ipykernel_23172\3892096801.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   f.set_xticklabels(['India','Australia','Brazil','Canada','Indonesia','New Zealand','Philippines','Qatar','Singapore','South Africa','Sri Lanka','Turkey','UAE','UK','USA'],rotation=90)

# %% [markdown]
# # Top 20 cities

# %%
temp1=df['City'].value_counts().head(20).reset_index()
plt.figure(figsize=(15,5))

f=sns.barplot(data=temp1,x='City',y='count')
f.set_xticklabels(labels= temp1['City'], rotation=90)
f.bar_label(f.containers[0])
plt.show()
# Out:
# C:\Users\naman\AppData\Local\Temp\ipykernel_23172\2378652735.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   f.set_xticklabels(labels= temp1['City'], rotation=90)

# %% [markdown]
# # Top 20 Cuisines

# %%
temp2=new_df['Cuisines'].value_counts().head(20).reset_index()
temp2
plt.figure(figsize=(15,5))

f=sns.barplot(data=temp2,x='Cuisines',y='count')
f.set_xticklabels(labels=temp2['Cuisines'],rotation=90)
f.bar_label(f.containers[0])
plt.show()
# Out:
# C:\Users\naman\AppData\Local\Temp\ipykernel_23172\2793381907.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   f.set_xticklabels(labels=temp2['Cuisines'],rotation=90)

# %% [markdown]
# # Price Range with Rating Text

# %%
sns.catplot(kind='count',data=df,x='Price range',col='Rating text',col_wrap=2,sharex=False,sharey=False)

# %% [markdown]
# # Aggregate Rating with Rating Text

# %%
sns.displot(kind='hist',data=df,x='Aggregate rating',hue='Rating text',height=5,aspect=2)

# %% [markdown]
# # Countries and Distribution of Rating Text

# %%
sns.catplot(kind='count',data=df,x='Rating text',col='Country Code',col_wrap=3,sharey=False,sharex=False)

# %% [markdown]
# # Countries and Price Range

# %%
sns.catplot(kind='count',data=df,x='Price range',col='Country Code',col_wrap=3,sharex=False,sharey=False)

# %% [markdown]
# # Geospatial Analysis

# %%
import geopandas as gpd

from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]

gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

# %%
world = gpd.read_file("https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip")

ax = world.plot(figsize=(15,10), color='lightgray', edgecolor='black')

gdf.plot(
    ax=ax,
    color='red',
    markersize=10
)

plt.show()

# %% [markdown]
# # Average Cost for two with Price Range Distribution along Countries

# %%
sns.catplot(kind='box',data=df,x='Average Cost for two',col='Country Code',hue='Price range',col_wrap=2,sharex=False,sharey=False)
